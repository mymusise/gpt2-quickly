# %% [markdown]
# <a href="https://colab.research.google.com/github/jshongtw/100WORDS-GENERATOR/blob/main/examples/100word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jshongtw/100WORDS-GENERATOR
# %cd 100WORDS-GENERATOR
# !pip install -r requirements.txt

# %%
#@title install google/sentencepiece

# !git clone https://github.com/google/sentencepiece.git 
# %cd sentencepiece
# !mkdir build
# %cd build
# !cmake ..
# !make -j $(nproc)
# !sudo make install
# !sudo ldconfig -v
# %cd ../../

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !head -n 20 /content/drive/MyDrive/100word/test/raw.txt
# Out:
# 學習運用與表達在作文上，透過學習單聊解了解人世間情感。
# 這個學期學了很多新的事物，不管是我喜歡的還是不喜歡的，我都有一定程度的收穫，而這次的成果只是一個冒號，國文還有許多神秘的面紗等著我發現。
# 在各種主題直接，我發現了感情存在於萬物之間，不只是在人與人，另外，這學期我創作了一首歌的歌詞，透過寫歌來表達感情。
# 這學期學習到了許多關於不同情感的文章，從愛情到師生情再到對物品的眷戀，各有不一樣的故事。在讀完這些文章後，經過學習和思考，做出的一些練習與感想。
# 比起百花爭豔的春，蟬聲如雷的夏和寒氣逼人的冬，落葉蕭瑟的秋是我最喜歡的季節。這是一篇不只描述秋天，而有深刻體會秋意的一篇作文。
# 從討論實驗教育到寫秋的足跡，努力去學習、去體會與國中完全不同的寫作方式。因為太想想寫出讓人驚豔的作品，導致在寫作時常常不滿意自己所寫的，塗塗改改，常常沒寫完。
# 本學期上完我學到許多國中沒學過的歷史人物，聽到他們的事蹟後讓我對國文充滿濃厚興趣，我也學到了許多修辭讓我可以應用到作文當中，讓我的作文更上一層樓。
# 這個國文報告整合了高一上學期的各種作業，因為這次大部分的作業都是知性的主題，國中時都沒有什麼練習過，所以目前的國文的水準還要繼續努力，多看書，讓知性作文可以寫得更好。
# 本學期國語文學期主題為〈戀●戀〉由古時的歸有光、史可法到現代的徐志摩、琦君、鍾怡雯的感情經歷展現情感的多樣性，也藉由生活中瑣事的平淡情感寫作抒情，讓我們練習抒情寫。
# 經課程學習之後，完成感情學習單體會詩人的感受以及親情寫作--藉物思人的表達方式，同時也有知性寫作-我看實驗教育及情感寫作-秋的足跡。
# 第一學期國語文學習歷程網址(檔案過大).。
# 這份文件裡有我對這學習國文課的收穫，還有段考時寫的作文，以及閱讀一篇關於感情有關的新詩寫出的賞析和心得，最後有一份和親情有關的作文。
# 國文課藉由課文延伸出不同主題，並將對人事物的感情記錄在紙上。
# 台北市中崙高中學年度第一學期高一國文科學習成果學習成果(戀。戀)----察覺生命裡的情感流動。
# 透過書寫作文及學習單培養我們對於文字的美感，訓練我們描述事物的能力，並增強我們對特定主題的思辯能力。
# 整理了段考作文與課文反思學習單，能更深入了解課文內容，使學習更有成效。
# 透過這四份作文，我體認到自己在寫作方面的不足，知道到自己有想法但卻寫不出來，希望這點能透過訓練好好改變，在看到自己作文時，常常不停的在反思，為何別人能夠做到而我不能，我希望能讓自己對自己的作文感到驕傲。
# 這學期的國文主題為「戀•戀」，由許多膾炙人口的文章組成，其中包括《再別康橋》、《項脊軒志》等充滿親情、愛情和友情的文學作品。我們由這個主題出發，藉由課堂學習單、段考作文表達出自己對感情的想法、反思。
# 了解「情」的表達並不只局限於人對人，世間萬物皆有情，對任何事物都可以有情感的表達。
# 從文章中感受作者想表達出來的感情，以及學習用文字表達自己的情感。

# %%
# !python cut_words.py
# !python build_tokenizer.py
# !head -n 20 /content/drive/MyDrive/100word/test/vocab.txt
# Out:
# reading /content/drive/MyDrive/100word/test/raw.txt
# total words: 2883858
# split data into 1 pieces
#   0% 0/44699 [00:00<?, ?it/s]Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.696 seconds.
# Prefix dict has been built successfully.
# 100% 44699/44699 [00:21<00:00, 2079.42it/s]
# [all_task done]
# dropping /content/drive/MyDrive/100word/test/raw.cut.temp.0.txt
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /content/drive/MyDrive/100word/test/raw.cut.txt
#   input_format:
#   model_prefix: spiece
#   model_type: BPE
#   vocab_size: 3000
#   self_test_sample_size: 0
#   character_coverage: 0.98
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 2
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /content/drive/MyDrive/100word/test/raw.cut.txt
# trainer_interface.cc(385) LOG(INFO) Loaded all 44698 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=4640205
# trainer_interface.cc(477) LOG(INFO) Done: 98.0017% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1096
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.980017
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 44698 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 44698
# trainer_interface.cc(537) LOG(INFO) Done! 55742
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=136767 min_freq=107
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=13483 size=20 all=46136 active=4491 piece=▁寫
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=8081 size=40 all=48331 active=6686 piece=▁時
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=6184 size=60 all=50275 active=8630 piece=▁都
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5070 size=80 all=52339 active=10694 piece=▁他
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4333 size=100 all=53705 active=12060 piece=▁以及
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=4265 min_freq=70
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3419 size=120 all=54884 active=3864 piece=▁會
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3000 size=140 all=56084 active=5064 piece=▁新
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2685 size=160 all=57298 active=6278 piece=▁過程
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2380 size=180 all=58006 active=6986 piece=▁.
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2204 size=200 all=58848 active=7828 piece=▁各
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2204 min_freq=54
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2028 size=220 all=59672 active=3687 piece=▁無
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1855 size=240 all=60749 active=4764 piece=▁或
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1722 size=260 all=61508 active=5523 piece=▁課程
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1557 size=280 all=62031 active=6046 piece=▁需
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1458 size=300 all=62727 active=6742 piece=▁喜歡
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1457 min_freq=47
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1361 size=320 all=63322 active=3727 piece=▁;
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1285 size=340 all=63575 active=3980 piece=▁三
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1191 size=360 all=64034 active=4439 piece=▁變
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1130 size=380 all=64421 active=4826 piece=▁包
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1055 size=400 all=64780 active=5185 piece=▁還是
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1054 min_freq=41
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=985 size=420 all=65370 active=3824 piece=▁困
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=943 size=440 all=66000 active=4454 piece=▁較
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=895 size=460 all=66439 active=4893 piece=▁歷史
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=840 size=480 all=66884 active=5338 piece=▁親
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=811 size=500 all=67297 active=5751 piece=王子
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=809 min_freq=37
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=754 size=520 all=67720 active=3785 piece=▁一步
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=734 size=540 all=68065 active=4130 piece=▁增加
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=703 size=560 all=68451 active=4516 piece=▁一定
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=684 size=580 all=68645 active=4710 piece=▁開始
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=659 size=600 all=68956 active=5021 piece=▁熟
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=658 min_freq=33
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=636 size=620 all=69260 active=3736 piece=▁理想
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=607 size=640 all=69549 active=4025 piece=▁訪
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=586 size=660 all=69963 active=4439 piece=▁這項
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=558 size=680 all=70165 active=4641 piece=▁建
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=541 size=700 all=70405 active=4881 piece=▁月
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=540 min_freq=31
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=526 size=720 all=70655 active=3757 piece=▁旅行
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=511 size=740 all=71009 active=4111 piece=▁準
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=500 size=760 all=71269 active=4371 piece=▁記錄
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=484 size=780 all=71627 active=4729 piece=▁學生
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=471 size=800 all=71861 active=4963 piece=▁那些
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=469 min_freq=29
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=457 size=820 all=72053 active=3786 piece=▁生平
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=442 size=840 all=72230 active=3963 piece=▁堂
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=426 size=860 all=72517 active=4250 piece=▁曾
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=415 size=880 all=72619 active=4352 piece=▁明白
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=402 size=900 all=72871 active=4604 piece=▁說明
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=401 min_freq=27
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=388 size=920 all=73078 active=3851 piece=▁變得
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=376 size=940 all=73238 active=4011 piece=▁不但
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=362 size=960 all=73508 active=4281 piece=▁一段
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=352 size=980 all=73762 active=4535 piece=▁熱
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=340 size=1000 all=74203 active=4976 piece=▁結果
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=340 min_freq=25
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=334 size=1020 all=74524 active=4030 piece=▁日常
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=319 size=1040 all=74852 active=4358 piece=▁類
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=311 size=1060 all=75018 active=4524 piece=▁搭配
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=304 size=1080 all=75277 active=4783 piece=愛的
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=297 size=1100 all=75534 active=5040 piece=▁深深
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=297 min_freq=23
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=288 size=1120 all=75611 active=3852 piece=▁仍
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=283 size=1140 all=75754 active=3995 piece=▁繼續
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=278 size=1160 all=75876 active=4117 piece=▁文筆
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=273 size=1180 all=76117 active=4358 piece=▁風格
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=269 size=1200 all=76357 active=4598 piece=▁還要
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=268 min_freq=22
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=263 size=1220 all=76547 active=4007 piece=▁判
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=258 size=1240 all=76706 active=4166 piece=▁遺
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=253 size=1260 all=76894 active=4354 piece=▁景色
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=247 size=1280 all=77098 active=4558 piece=▁戲
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=244 size=1300 all=77288 active=4748 piece=▁詩人
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=243 min_freq=21
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=236 size=1320 all=77470 active=4035 piece=▁所學
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=232 size=1340 all=77654 active=4219 piece=▁陌
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=227 size=1360 all=77736 active=4301 piece=六橋
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=223 size=1380 all=77865 active=4430 piece=▁本學期
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=219 size=1400 all=78005 active=4570 piece=▁終
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=219 min_freq=20
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=214 size=1420 all=78166 active=4029 piece=▁滿滿
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=208 size=1440 all=78326 active=4189 piece=▁試著
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=203 size=1460 all=78456 active=4319 piece=▁挑選
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=199 size=1480 all=78545 active=4408 piece=▁魯迅
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=194 size=1500 all=78625 active=4488 piece=▁困境
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=193 min_freq=19
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=190 size=1520 all=78747 active=4054 piece=時候
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=187 size=1540 all=78918 active=4225 piece=▁段落
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=184 size=1560 all=78994 active=4301 piece=▁房間
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=180 size=1580 all=79166 active=4473 piece=▁[
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=178 size=1600 all=79267 active=4574 piece=▁演講
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=178 min_freq=18
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=176 size=1620 all=79378 active=4067 piece=▁這件
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=173 size=1640 all=79521 active=4210 piece=▁升
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=171 size=1660 all=79620 active=4309 piece=▁平凡
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=169 size=1680 all=79758 active=4447 piece=▁處理
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=165 size=1700 all=79859 active=4548 piece=▁富
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=165 min_freq=18
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=162 size=1720 all=80013 active=4130 piece=▁九
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=159 size=1740 all=80169 active=4286 piece=▁秋
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=157 size=1760 all=80313 active=4430 piece=▁而言
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=154 size=1780 all=80415 active=4532 piece=▁真是
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=151 size=1800 all=80500 active=4617 piece=方面
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=151 min_freq=17
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=149 size=1820 all=80582 active=4102 piece=▁融合
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=146 size=1840 all=80598 active=4118 piece=▁保護
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=144 size=1860 all=80651 active=4171 piece=▁黃
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=142 size=1880 all=80733 active=4253 piece=▁專題
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=139 size=1900 all=80858 active=4378 piece=▁頭
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=139 min_freq=16
# trainer_interface.cc(615) LOG(INFO) Saving model: spiece.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: spiece.vocab
# [PAD]
# [UNK]
# [CLS]
# [SEP]
# [MASK]
# ?
# □
# 。
# 【
# 】
# 一
# 七
# 萬
# 三
# 上
# 下
# 不
# 與
# 且
# 世

# %%
# !python predata.py
# !python train.py --epochs 5
# Out:
# 2021-07-24 03:40:03.651671: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# reading /content/drive/MyDrive/100word/test/raw.txt
# total words: 2883858
# merging data
# merged
# num of task:  1
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
#   0% 0/1913 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (2820 > 64). Running this sequence through the model will result in indexing errors
# 100% 1913/1913 [00:12<00:00, 154.32it/s]
# assert 0 with 178486
# [all_task done]
# 2021-07-24 03:40:20.365074: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-24 03:40:22.037765: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-07-24 03:40:22.068307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.068942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-07-24 03:40:22.068988: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-24 03:40:22.071528: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-07-24 03:40:22.071599: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-07-24 03:40:22.073283: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-07-24 03:40:22.073617: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-07-24 03:40:22.075588: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.10
# 2021-07-24 03:40:22.076413: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-07-24 03:40:22.076609: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-07-24 03:40:22.076713: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.077404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.078011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-24 03:40:22.078560: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.079108: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-07-24 03:40:22.079205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.079799: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.080419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-24 03:40:22.080472: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-24 03:40:22.701337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-24 03:40:22.701390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-07-24 03:40:22.701407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-07-24 03:40:22.701561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.702197: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.702763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-24 03:40:22.703276: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-07-24 03:40:22.703323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13837 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# loading /content/drive/MyDrive/100word/test/data_0.pickle
# (178485, 63) (178485, 63) int64 int64
# file /content/drive/MyDrive/100word/models/config.json not found
# 2021-07-24 03:40:23.176531: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:absl:using Adamw optimizer
# INFO:absl:gradient_clip_norm=1.000000
# 2021-07-24 03:40:23.213218: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2021-07-24 03:40:23.213261: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# 2021-07-24 03:40:23.213303: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1611] Profiler found 1 GPUs
# 2021-07-24 03:40:23.214253: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcupti.so.11.0
# 2021-07-24 03:40:23.307345: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.
# 2021-07-24 03:40:23.307575: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1743] CUPTI activity buffer flushed
# 2021-07-24 03:40:23.781226: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:695] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# op: "TensorSliceDataset"
# input: "Placeholder/_0"
# input: "Placeholder/_1"
# attr {
#   key: "Toutput_types"
#   value {
#     list {
#       type: DT_INT64
#       type: DT_INT64
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 63
#         }
#       }
#       shape {
#         dim {
#           size: 63
#         }
#       }
#     }
#   }
# }
#
# 2021-07-24 03:40:23.885092: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-07-24 03:40:23.885538: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2199995000 Hz
# Epoch 1/5
# The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 2021-07-24 03:40:35.941775: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-07-24 03:40:36.459324: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
#    1/1000 [..............................] - ETA: 3:30:09 - loss: 8.1573 - accuracy: 0.0000e+002021-07-24 03:40:36.660448: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2021-07-24 03:40:36.660497: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
#    2/1000 [..............................] - ETA: 8:24 - loss: 8.1423 - accuracy: 0.0000e+00   2021-07-24 03:40:37.029370: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2021-07-24 03:40:37.030456: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1743] CUPTI activity buffer flushed
# 2021-07-24 03:40:37.183199: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 1115 callback api events and 1112 activity events.
# 2021-07-24 03:40:37.200475: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.
# 2021-07-24 03:40:37.232180: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37
# 2021-07-24 03:40:37.255756: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37/7ed4085aa07a.trace.json.gz
# 2021-07-24 03:40:37.306623: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37
# 2021-07-24 03:40:37.316134: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37/7ed4085aa07a.memory_profile.json.gz
# 2021-07-24 03:40:37.334802: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37Dumped tool data for xplane.pb to /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37/7ed4085aa07a.xplane.pb
# Dumped tool data for overview_page.pb to /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37/7ed4085aa07a.overview_page.pb
# Dumped tool data for input_pipeline.pb to /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37/7ed4085aa07a.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37/7ed4085aa07a.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to /content/drive/MyDrive/100word/models//logs/train/plugins/profile/2021_07_24_03_40_37/7ed4085aa07a.kernel_stats.pb
#
#    5/1000 [..............................] - ETA: 4:10 - loss: 8.1443 - accuracy: 0.0000e+00WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0616s vs `on_train_batch_begin` time: 0.0749s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0616s vs `on_train_batch_begin` time: 0.0749s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0616s vs `on_train_batch_end` time: 0.0759s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0616s vs `on_train_batch_end` time: 0.0759s). Check your callbacks.
# 1000/1000 [==============================] - 58s 46ms/step - loss: 5.4722 - accuracy: 0.1361
# Epoch 2/5
#   38/1000 [>.............................] - ETA: 44s - loss: 4.6825 - accuracy: 0.2011

# %%
# !python predict.py
